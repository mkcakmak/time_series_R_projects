# %%
library(readxl)
library(IRdisplay)
library(magrittr)
library(tidyverse)
library(scales)
library(gridExtra)
#library(forecast)
library(ggthemes)
theme_set(theme_economist())

source("sim_random_walk_function.R")
source("compare_models_function.R")
source("sim_stationary_example_function.R")

print("Loading is completed")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ tidyr::extract()   masks magrittr::extract()
# ✖ dplyr::filter()    masks stats::filter()
# ✖ dplyr::lag()       masks stats::lag()
# ✖ purrr::set_names() masks magrittr::set_names()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: 'scales'
#
#
# The following object is masked from 'package:purrr':
#
#     discard
#
#
# The following object is masked from 'package:readr':
#
#     col_factor
#
#
#
# Attaching package: 'gridExtra'
#
#
# The following object is masked from 'package:dplyr':
#
#     combine
# [1] "Loading is completed"

# %% [markdown]
# ## Time Series Data Overview

# %%
compare.models(n=100)
# Out:
# plot without title

# %% [markdown]
# ### Simulate Random Walk

# %%
dat <- sim.random.walk()

dat %>% ggplot(aes(t, X)) + geom_line() + xlab("T") + ylab("X") + ggtitle("Time Series Plot")
# Out:
# plot without title

# %%
acf(dat$X)
# Out:
# Plot with title "Series  dat$X"

# %%
acf(dat$X,type = "partial")
# Out:
# Plot with title "Series  dat$X"

# %% [markdown]
# ### Stationarity

# %%
df <- sim.stationary.example(n=1000)
head(df) ; dim(df)
# Out:
#   t X1          X2       X3
# 1 1  0.31066132 2.471611  1.3601496
# 2 2 -0.30822955 2.762806  1.7213436
# 3 3 -1.15773354 2.929636 -0.9038226
# 4 4 -1.43791578 3.830079 -2.1381069
# 5 5  0.03501795 3.751600 -0.7794356
# 6 6  0.19434386 6.131618  0.3282359
# [1] 1000    4

# %%
plot(ts(df$X1))
plot(ts(df$X2))
plot(ts(df$X3))
# Out:
# plot without title
# plot without title
# plot without title

# %%
acf(df$X1)
acf(df$X2)
acf(df$X3)
# Out:
# Plot with title "Series  df$X1"
# Plot with title "Series  df$X2"
# Plot with title "Series  df$X3"

# %% [markdown]
# ### Differencing

# %%
diff <- ts(diff(df$X1))
plot(diff)
acf(diff)
# Out:
# plot without title
# Plot with title "Series  diff"

# %% [markdown]
# ### Detrending

# %%
plot(ts(df$X2))
plot(acf(df$X2))
# Out:
# plot without title
# Plot with title "Series  df$X2"

# %%
detrended <- resid(lm(X2 ~ t, data = df))

# %%
plot(ts(detrended))
acf(detrended)
# Out:
# plot without title
# Plot with title "Series  detrended"

# %% [markdown]
# ### Loading Data

# %%
df <- read.csv("Mass Monthly Unemployment Rate.csv")
head(df)
# Out:
#   DATE       MAURN
# 1 1976-01-01 11.6
# 2 1976-02-01 11.3
# 3 1976-03-01 10.9
# 4 1976-04-01  9.9
# 5 1976-05-01  9.4
# 6 1976-06-01  9.8

# %%
class(df$DATE)
# Out:
# [1] "character"

# %%
df$DATE <- as.Date(df$DATE)

# %%
head(df)
# Out:
#   DATE       MAURN
# 1 1976-01-01 11.6
# 2 1976-02-01 11.3
# 3 1976-03-01 10.9
# 4 1976-04-01  9.9
# 5 1976-05-01  9.4
# 6 1976-06-01  9.8

# %%
ggplot(df, aes(x = DATE, y = MAURN)) + geom_line()
# Out:
# plot without title

# %%
plot(ts(df$MAURN))
# Out:
# plot without title

# %%
acf(df$MAURN)
# Out:
# Plot with title "Series  df$MAURN"

# %% [markdown]
# ### Fitting Models(Transforming for Stationary & Identifying Model Parameters)

# %%
library(forecast)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
# Fit AR model
ar.model <- auto.arima(df$MAURN, max.d = 0, max.q = 0, allowdrift = TRUE)
ar.model
# Out:
# Series: df$MAURN
# ARIMA(1,0,0) with non-zero mean
#
# Coefficients:
#          ar1    mean
#       0.9787  5.7425
# s.e.  0.0101  0.8498
#
# sigma^2 = 0.2:  log likelihood = -325.44
# AIC=656.88   AICc=656.93   BIC=669.7

# %%
# MA model
ma.model <- auto.arima(df$MAURN, max.d = 0, max.p = 0, allowdrift = TRUE)
ma.model
# Out:
# Series: df$MAURN
# ARIMA(0,0,5) with non-zero mean
#
# Coefficients:
#          ma1     ma2     ma3     ma4     ma5    mean
#       1.3646  1.7103  1.4882  1.2714  0.4804  5.4588
# s.e.  0.0368  0.0492  0.0578  0.0393  0.0350  0.1507
#
# sigma^2 = 0.229:  log likelihood = -361.03
# AIC=736.05   AICc=736.27   BIC=765.95

# %%
# ARMA model
arma.model <- auto.arima(df$MAURN, max.d = 0,  allowdrift = TRUE)
arma.model
# Out:
# Series: df$MAURN
# ARIMA(3,0,2) with non-zero mean
#
# Coefficients:
#           ar1     ar2     ar3     ma1     ma2    mean
#       -0.2267  0.5998  0.5573  1.3361  0.8876  5.7038
# s.e.   0.0885  0.0544  0.0569  0.0544  0.0221  0.7764
#
# sigma^2 = 0.1693:  log likelihood = -280.15
# AIC=574.3   AICc=574.51   BIC=604.19

# %%
# ARIMA model
arima.model <- auto.arima(df$MAURN, allowdrift = TRUE)
arima.model
# Out:
# Series: df$MAURN
# ARIMA(4,1,2)
#
# Coefficients:
#          ar1      ar2      ar3     ar4      ma1     ma2
#       1.0029  -0.1834  -0.3982  0.4872  -1.1149  0.2512
# s.e.  0.0708   0.0750   0.0560  0.0394   0.0793  0.0711
#
# sigma^2 = 0.1509:  log likelihood = -247.45
# AIC=508.9   AICc=509.12   BIC=538.78

# %% [markdown]
# ### Check The Resisduals of the Model Fit

# %%
# Calculate residuals of each model
ar.residual <- resid(ar.model)
ma.residual <- resid(ma.model)
arma.residual <- resid(arma.model)
arima.residual <- resid(arima.model)

# %%
plot(ar.residual)
plot(ma.residual)
plot(arma.residual)
plot(arima.residual)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# plot PACF 
pacf(ar.residual)
pacf(ma.residual)
pacf(arma.residual)
pacf(arima.residual)
# Out:
# Plot with title "Series  ar.residual"
# Plot with title "Series  ma.residual"
# Plot with title "Series  arma.residual"
# Plot with title "Series  arima.residual"

# %% [markdown]
# Generally we are expecting autocorrelation at the first few lags in confidence interval

# %%
# Run Ljung Box Test
Box.test(ar.residual,type = "Ljung-Box", lag = 1)
Box.test(ma.residual,type = "Ljung-Box", lag = 1)
Box.test(arma.residual,type = "Ljung-Box", lag = 1)
Box.test(arima.residual,type = "Ljung-Box", lag = 1)
# Out:
# 	Box-Ljung test
#
# data:  ar.residual
# X-squared = 0.88802, df = 1, p-value = 0.346
# 	Box-Ljung test
#
# data:  ma.residual
# X-squared = 0.56386, df = 1, p-value = 0.4527
# 	Box-Ljung test
#
# data:  arma.residual
# X-squared = 0.96747, df = 1, p-value = 0.3253
# 	Box-Ljung test
#
# data:  arima.residual
# X-squared = 0.0032696, df = 1, p-value = 0.9544

# %%
### Making a forecast for each model
ar.forecast <- forecast(ar.model,h = 24, level = 80)
ma.forecast <- forecast(ma.model,h = 24, level = 80)
arma.forecast <- forecast(arma.model,h = 24, level = 80)
arima.forecast <- forecast(arima.model,h = 24, level = 80)

# %%
g1 <- autoplot(ar.forecast)
g2 <- autoplot(ma.forecast)
g3 <- autoplot(arma.forecast)
g4 <- autoplot(arima.forecast)

grid.arrange(g1,g2,g3,g4, nrow = 4, ncol =1)
# Out:
# plot without title

# %% [markdown]
# ### Fitting Seasonal Trend Loess (STL) Decomposition Models

# %%
# Transform to time series object; need to specify frequency

df.ts <-ts(df$MAURN, frequency = 12)

# %%
# fit stl model
stl.model <-stl(df.ts, s.window = "periodic")
stl.model
# Out:
#  Call:
#  stl(x = df.ts, s.window = "periodic")
#
# Components
#           seasonal     trend     remainder
# Jan  1  0.74477180 10.748465  1.067627e-01
# Feb  1  0.50413417 10.545432  2.504338e-01
# Mar  1  0.32481073 10.342398  2.327908e-01
# Apr  1 -0.22325989 10.145686 -2.242641e-02
# May  1 -0.20087608  9.948974 -3.480981e-01
# Jun  1  0.20054259  9.756682 -1.572243e-01
# Jul  1  0.17241583  9.564389 -3.680511e-02
# Aug  1 -0.15990287  9.374141 -2.142383e-01
# Sep  1 -0.05131239  9.183893 -1.325806e-01
# Oct  1 -0.52495659  9.017889 -1.929327e-01
# Nov  1 -0.43269167  8.851886 -1.191940e-01
# Dec  1 -0.35367561  8.711877 -1.582010e-01
# Jan  2  0.74477180  8.571867  1.833607e-01
# Feb  2  0.50413417  8.439371  2.564945e-01
# Mar  2  0.32481073  8.306875  1.683141e-01
# Apr  2 -0.22325989  8.167854 -4.459461e-02
# May  2 -0.20087608  8.028834 -2.279578e-01
# Jun  2  0.20054259  7.869876  1.295811e-01
# Jul  2  0.17241583  7.710919 -8.333469e-02
# Aug  2 -0.15990287  7.546451  2.134515e-01
# Sep  2 -0.05131239  7.381984  1.693284e-01
# Oct  2 -0.52495659  7.226116 -1.011594e-01
# Nov  2 -0.43269167  7.070248 -3.755626e-02
# Dec  2 -0.35367561  6.927040 -3.733646e-01
# Jan  3  0.74477180  6.783832 -2.860421e-02
# Feb  3  0.50413417  6.656816  3.904946e-02
# Mar  3  0.32481073  6.529800  4.538894e-02
# Apr  3 -0.22325989  6.427741 -2.044808e-01
# May  3 -0.20087608  6.325681 -2.248049e-01
# Oct 40 -0.52495659  4.549628  1.753284e-01
# Nov 40 -0.43269167  4.463216  6.947573e-02
# Dec 40 -0.35367561  4.369879  8.379614e-02
# Jan 41  0.74477180  4.276543 -2.213148e-01
# Feb 41  0.50413417  4.188024 -9.215842e-02
# Mar 41  0.32481073  4.099506 -1.243162e-01
# Apr 41 -0.22325989  4.026328 -3.067622e-03
# May 41 -0.20087608  3.953150 -5.227344e-02
# Jun 41  0.20054259  3.902368 -1.029108e-01
# Jul 41  0.17241583  3.851587 -2.400280e-02
# Aug 41 -0.15990287  3.821316 -6.141335e-02
# Sep 41 -0.05131239  3.791045 -1.397331e-01
# Oct 41 -0.52495659  3.775310  4.964688e-02
# Nov 41 -0.43269167  3.759574 -2.688228e-02
# Dec 41 -0.35367561  3.757715 -4.039104e-03
# Jan 42  0.74477180  3.755855 -1.006273e-01
# Feb 42  0.50413417  3.758918  3.694769e-02
# Mar 42  0.32481073  3.761981 -8.679155e-02
# Apr 42 -0.22325989  3.760464 -3.720382e-02
# May 42 -0.20087608  3.758947  1.419295e-01
# Jun 42  0.20054259  3.747171  5.228659e-02
# Jul 42  0.17241583  3.735395  9.218913e-02
# Aug 42 -0.15990287  3.711646  1.482567e-01
# Sep 42 -0.05131239  3.687897 -3.658488e-02
# Oct 42 -0.52495659  3.655887  6.907001e-02
# Nov 42 -0.43269167  3.623876  8.815786e-03
# Dec 42 -0.35367561  3.589687  6.398904e-02
# Jan 43  0.74477180  3.555497 -2.002691e-01
# Feb 43  0.50413417  3.520250 -2.438438e-02
# Mar 43  0.32481073  3.485003 -1.098139e-01
# Apr 43 -0.22325989  3.449651 -2.639115e-02
# May 43 -0.20087608  3.414299  8.657716e-02
# Jun 43  0.20054259  3.377255  1.222025e-01
# Jul 43  0.17241583  3.340211  8.737326e-02
# Aug 43 -0.15990287  3.298897  6.100621e-02
# Sep 43 -0.05131239  3.257582 -1.062700e-01
# Oct 43 -0.52495659  3.212929  1.120274e-01
# Nov 43 -0.43269167  3.168276 -3.558423e-02
# Dec 43 -0.35367561  3.125816  2.785991e-02
# Jan 44  0.74477180  3.083356 -1.281273e-01
# Feb 44  0.50413417  3.047301 -1.514353e-01
# Mar 44  0.32481073  3.011247 -3.605751e-02
# Apr 44 -0.22325989  2.981642 -5.838210e-02
# May 44 -0.20087608  2.952037  1.488389e-01
# Jun 44  0.20054259  2.923205 -2.374730e-02
# Jul 44  0.17241583  2.894372  3.321197e-02
# Aug 44 -0.15990287  2.865966  9.393658e-02
# Sep 44 -0.05131239  2.837560 -8.624797e-02
# Oct 44 -0.52495659  2.809122  1.158343e-01
# Nov 44 -0.43269167  2.780684 -4.799253e-02
# Dec 44 -0.35367561  2.751643  2.033055e-03
# Jan 45  0.74477180  2.722601 -6.737270e-02

# %%
#plot model fit
autoplot(stl.model)
# Out:
# plot without title

# %%
# make forecast
stl.forecast <- forecast(stl.model, h = 24, level = 80)

autoplot(stl.forecast)
# Out:
# plot without title
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
